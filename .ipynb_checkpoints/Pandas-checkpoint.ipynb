# %% [markdown]
# # Pandas
#
# We read in some data from a CSV file. CSV files can be output by any spreadsheet software, and are plain text, so make a great way to share data.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("train.csv")

# %% [markdown]
# Display the first n rows of the data by df.head(n)

# %%
df.head(5)
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %% [markdown]
# ## The basics

# %%
df.dtypes
# Out:
# ID           int64
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.shape
# Out:
# (333, 15)

# %%
df.columns
# Out:
# Index([u'ID', u'crim', u'zn', u'indus', u'chas', u'nox', u'rm', u'age', u'dis',
#        u'rad', u'tax', u'ptratio', u'black', u'lstat', u'medv'],
#       dtype='object')

# %%
type(df.ID), type(df)
df.ID
# Out:
# 0        1
# 1        2
# 2        4
# 3        5
# 4        7
# 5       11
# 6       12
# 7       13
# 8       14
# 9       15
# 10      16
# 11      17
# 12      19
# 13      21
# 14      22
# 15      23
# 16      24
# 17      28
# 18      31
# 19      32
# 20      35
# 21      39
# 22      40
# 23      41
# 24      43
# 25      44
# 26      45
# 27      46
# 28      47
# 29      48
#       ...
# 303    465
# 304    466
# 305    467
# 306    468
# 307    469
# 308    470
# 309    472
# 310    473
# 311    475
# 312    477
# 313    478
# 314    479
# 315    480
# 316    481
# 317    482
# 318    484
# 319    485
# 320    487
# 321    488
# 322    489
# 323    491
# 324    492
# 325    493
# 326    494
# 327    498
# 328    500
# 329    502
# 330    503
# 331    504
# 332    506
# Name: ID, dtype: int64

# %% [markdown]
# ## Querying

# %%
df.age > 50
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
# 5       True
# 6       True
# 7      False
# 8       True
# 9       True
# 10      True
# 11     False
# 12     False
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 303     True
# 304    False
# 305     True
# 306     True
# 307     True
# 308     True
# 309     True
# 310     True
# 311     True
# 312     True
# 313     True
# 314     True
# 315     True
# 316     True
# 317     True
# 318    False
# 319    False
# 320     True
# 321     True
# 322     True
# 323     True
# 324     True
# 325     True
# 326     True
# 327     True
# 328     True
# 329     True
# 330     True
# 331     True
# 332     True
# Name: age, dtype: bool

# %%
(df.age > 50).sum()
# Out:
# 236

# %%
(df.age > 50).sum()/ float(len(df.age))
# Out:
# 0.70870870870870872

# %%
df.age.shape[0]
# Out:
# 333

# %%
(df.age > 50).mean()
# Out:
# 0.70870870870870872

# %%
df[df.age > 50]
# Out:
#       ID      crim    zn  indus  chas     nox     rm    age     dis  rad  tax  \
# 0      1   0.00632  18.0   2.31     0  0.5380  6.575   65.2  4.0900    1  296
# 1      2   0.02731   0.0   7.07     0  0.4690  6.421   78.9  4.9671    2  242
# 3      5   0.06905   0.0   2.18     0  0.4580  7.147   54.2  6.0622    3  222
# 4      7   0.08829  12.5   7.87     0  0.5240  6.012   66.6  5.5605    5  311
# 5     11   0.22489  12.5   7.87     0  0.5240  6.377   94.3  6.3467    5  311
# 6     12   0.11747  12.5   7.87     0  0.5240  6.009   82.9  6.2267    5  311
# 8     14   0.62976   0.0   8.14     0  0.5380  5.949   61.8  4.7075    4  307
# 9     15   0.63796   0.0   8.14     0  0.5380  6.096   84.5  4.4619    4  307
# 10    16   0.62739   0.0   8.14     0  0.5380  5.834   56.5  4.4986    4  307
# 13    21   1.25179   0.0   8.14     0  0.5380  5.570   98.1  3.7979    4  307
# 14    22   0.85204   0.0   8.14     0  0.5380  5.965   89.2  4.0123    4  307
# ...

# %%
df[(df.age > 50) & (df.ID < 40)]
# Out:
#     ID     crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0    1  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1    2  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 3    5  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 4    7  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 5   11  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 6   12  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# 8   14  0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 9   15  0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 10  16  0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# 13  21  1.25179   0.0   8.14     0  0.538  5.570   98.1  3.7979    4  307
# 14  22  0.85204   0.0   8.14     0  0.538  5.965   89.2  4.0123    4  307
# 15  23  1.23247   0.0   8.14     0  0.538  6.142   91.7  3.9769    4  307
# ...

# %%
df["age"] = df["age"].astype(float)

# %%
df["age"]
# Out:
# 0       65.2
# 1       78.9
# 2       45.8
# 3       54.2
# 4       66.6
# 5       94.3
# 6       82.9
# 7       39.0
# 8       61.8
# 9       84.5
# 10      56.5
# 11      29.3
# 12      36.6
# 13      98.1
# 14      89.2
# 15      91.7
# 16     100.0
# 17      88.8
# 18      94.1
# 19     100.0
# 20      96.9
# 21      30.2
# 22      21.8
# 23      15.8
# 24       6.6
# 25       6.5
# 26      40.0
# 27      33.8
# 28      33.3
# 29      85.5
#        ...
# 303     65.4
# 304     48.2
# 305     84.7
# 306     94.5
# 307     71.0
# 308     56.7
# 309     90.7
# 310     75.0
# 311     95.4
# 312     93.6
# 313     97.3
# 314     96.7
# 315     88.0
# 316     64.7
# 317     74.9
# 318     40.3
# 319     41.9
# 320     79.8
# 321     53.2
# 322     92.7
# 323     98.0
# 324     98.8
# 325     83.5
# 326     54.0
# 327     70.6
# 328     73.5
# 329     69.1
# 330     76.7
# 331     91.0
# 332     80.8
# Name: age, dtype: float64

# %%
df["age"] = df["age"].astype(int)

# %%
df["age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 303    False
# 304    False
# 305    False
# 306    False
# 307    False
# 308    False
# 309    False
# 310    False
# 311    False
# 312    False
# 313    False
# 314    False
# 315    False
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# 321    False
# 322    False
# 323    False
# 324    False
# 325    False
# 326    False
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# 332    False
# Name: age, dtype: bool

# %%
df.isnull()
# Out:
#         ID   crim     zn  indus   chas    nox     rm    age    dis    rad  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# 5    False  False  False  False  False  False  False  False  False  False
# 6    False  False  False  False  False  False  False  False  False  False
# 7    False  False  False  False  False  False  False  False  False  False
# 8    False  False  False  False  False  False  False  False  False  False
# 9    False  False  False  False  False  False  False  False  False  False
# 10   False  False  False  False  False  False  False  False  False  False
# 11   False  False  False  False  False  False  False  False  False  False
# ...

# %%
df["age"].isnull().sum()
# Out:
# 0

# %%
df.age.hist()
plt.show()

# %%
df.black.hist(bins=np.arange(0, 1000, 100))

# %%
plt.scatter(df.ID, df.age)

# %%
target = df["medv"]
input_ftrs = df.drop(['age'], axis = 1)

# %%
new_col = np.random.randint(1,100, size = df.shape[0])

# %%
new_col
# Out:
# array([27, 91,  5, 30, 93, 19, 54,  3, 54, 86, 89, 85, 10, 66, 22, 45, 38,
#        90, 24, 96, 69, 45, 18, 48,  8, 47, 55, 60,  7, 60, 18, 71, 25, 38,
#        14, 20, 58, 93, 58,  9, 83, 39, 19, 80, 20, 94, 67, 73, 83, 12, 88,
#         3, 66, 23, 20, 34, 70, 65, 11, 82, 10, 17, 61, 54, 91, 99, 63, 58,
#        53, 80, 43, 48, 69, 23, 91, 67, 51, 57, 97, 84, 33, 44, 54, 47, 56,
#        74, 36, 20,  1, 94, 77, 53, 99, 96, 61, 19, 90,  4, 30,  9, 49,  7,
#        64, 86, 54, 68, 80, 48, 67, 21, 18, 67, 75, 96, 75, 64, 32, 74, 25,
#        17, 69,  6, 59,  8, 55, 61, 88, 76, 55, 16, 98, 30, 13,  1, 99,  5,
#        20, 29,  4, 55, 90, 21, 17, 94,  2, 44, 26, 85, 43, 44, 76,  3, 19,
#        25, 11,  6, 59, 53, 16, 61, 36,  1,  6, 95, 60, 37, 69, 63, 40, 30,
#        79, 72, 39, 81, 11, 83,  1, 70, 69, 65, 64, 20, 20, 77, 50, 16,  6,
#        62, 84, 19, 15, 11, 87, 54,  9, 75, 22, 12, 92, 51, 95, 60, 62, 31,
# ...

# %%
df["new_col"] = new_col

# %%
def odd_even(x):
    if (x%2) == 0:
        return "even"
    else:
        return "odd"
df["new_col"] = df["new_col"].apply(odd_even)

# %%
df.new_col
# Out:
# 0       odd
# 1       odd
# 2       odd
# 3      even
# 4       odd
# 5       odd
# 6      even
# 7       odd
# 8      even
# 9      even
# 10      odd
# 11      odd
# 12     even
# 13     even
# 14     even
# 15      odd
# 16     even
# 17     even
# 18     even
# 19     even
# 20      odd
# 21      odd
# 22     even
# 23     even
# 24     even
# 25      odd
# 26      odd
# 27     even
# 28      odd
# 29     even
#        ...
# 303     odd
# 304    even
# 305     odd
# 306     odd
# 307    even
# 308    even
# 309    even
# 310     odd
# 311     odd
# 312    even
# 313     odd
# 314     odd
# 315     odd
# 316     odd
# 317    even
# 318     odd
# 319     odd
# 320    even
# 321    even
# 322     odd
# 323    even
# 324    even
# 325    even
# 326     odd
# 327     odd
# 328     odd
# 329     odd
# 330     odd
# 331    even
# 332    even
# Name: new_col, dtype: object

# %%
df["new_col"] = df["new_col"].map({"even": 0, "odd": 1})

# %%
df.new_col
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
# 5      1
# 6      0
# 7      1
# 8      0
# 9      0
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     0
# 18     0
# 19     0
# 20     1
# 21     1
# 22     0
# 23     0
# 24     0
# 25     1
# 26     1
# 27     0
# 28     1
# 29     0
#       ..
# 303    1
# 304    0
# 305    1
# 306    1
# 307    0
# 308    0
# 309    0
# 310    1
# 311    1
# 312    0
# 313    1
# 314    1
# 315    1
# 316    1
# 317    0
# 318    1
# 319    1
# 320    0
# 321    0
# 322    1
# 323    0
# 324    0
# 325    0
# 326    1
# 327    1
# 328    1
# 329    1
# 330    1
# 331    0
# 332    0
# Name: new_col, dtype: int64

# %%
new_col
# Out:
# array([27, 91,  5, 30, 93, 19, 54,  3, 54, 86, 89, 85, 10, 66, 22, 45, 38,
#        90, 24, 96, 69, 45, 18, 48,  8, 47, 55, 60,  7, 60, 18, 71, 25, 38,
#        14, 20, 58, 93, 58,  9, 83, 39, 19, 80, 20, 94, 67, 73, 83, 12, 88,
#         3, 66, 23, 20, 34, 70, 65, 11, 82, 10, 17, 61, 54, 91, 99, 63, 58,
#        53, 80, 43, 48, 69, 23, 91, 67, 51, 57, 97, 84, 33, 44, 54, 47, 56,
#        74, 36, 20,  1, 94, 77, 53, 99, 96, 61, 19, 90,  4, 30,  9, 49,  7,
#        64, 86, 54, 68, 80, 48, 67, 21, 18, 67, 75, 96, 75, 64, 32, 74, 25,
#        17, 69,  6, 59,  8, 55, 61, 88, 76, 55, 16, 98, 30, 13,  1, 99,  5,
#        20, 29,  4, 55, 90, 21, 17, 94,  2, 44, 26, 85, 43, 44, 76,  3, 19,
#        25, 11,  6, 59, 53, 16, 61, 36,  1,  6, 95, 60, 37, 69, 63, 40, 30,
#        79, 72, 39, 81, 11, 83,  1, 70, 69, 65, 64, 20, 20, 77, 50, 16,  6,
#        62, 84, 19, 15, 11, 87, 54,  9, 75, 22, 12, 92, 51, 95, 60, 62, 31,
# ...

# %%
new_col2 = (new_col).astype(float)

# %%
mask = [2,13,4,9]

# %%
new_col2[np.asarray(mask)] = np.nan

# %%
new_col2
# Out:
# array([ 27.,  91.,  nan,  30.,  nan,  19.,  54.,   3.,  54.,  nan,  89.,
#         85.,  10.,  nan,  22.,  45.,  38.,  90.,  24.,  96.,  69.,  45.,
#         18.,  48.,   8.,  47.,  55.,  60.,   7.,  60.,  18.,  71.,  25.,
#         38.,  14.,  20.,  58.,  93.,  58.,   9.,  83.,  39.,  19.,  80.,
#         20.,  94.,  67.,  73.,  83.,  12.,  88.,   3.,  66.,  23.,  20.,
#         34.,  70.,  65.,  11.,  82.,  10.,  17.,  61.,  54.,  91.,  99.,
#         63.,  58.,  53.,  80.,  43.,  48.,  69.,  23.,  91.,  67.,  51.,
#         57.,  97.,  84.,  33.,  44.,  54.,  47.,  56.,  74.,  36.,  20.,
#          1.,  94.,  77.,  53.,  99.,  96.,  61.,  19.,  90.,   4.,  30.,
#          9.,  49.,   7.,  64.,  86.,  54.,  68.,  80.,  48.,  67.,  21.,
#         18.,  67.,  75.,  96.,  75.,  64.,  32.,  74.,  25.,  17.,  69.,
#          6.,  59.,   8.,  55.,  61.,  88.,  76.,  55.,  16.,  98.,  30.,
#         13.,   1.,  99.,   5.,  20.,  29.,   4.,  55.,  90.,  21.,  17.,
# ...

# %%
df["new_col2"] = new_col2

# %%
df.isnull()
# Out:
#         ID   crim     zn  indus   chas    nox     rm    age    dis    rad  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# 5    False  False  False  False  False  False  False  False  False  False
# 6    False  False  False  False  False  False  False  False  False  False
# 7    False  False  False  False  False  False  False  False  False  False
# 8    False  False  False  False  False  False  False  False  False  False
# 9    False  False  False  False  False  False  False  False  False  False
# 10   False  False  False  False  False  False  False  False  False  False
# 11   False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.isnull().any()
# Out:
# ID          False
# crim        False
# zn          False
# indus       False
# chas        False
# nox         False
# rm          False
# age         False
# dis         False
# rad         False
# tax         False
# ptratio     False
# black       False
# lstat       False
# medv        False
# new_col     False
# new_col2     True
# dtype: bool

# %%
df["new_col2"].isnull().any()
# Out:
# True

# %%
df["new_col2"].isnull().sum()
# Out:
# 4

# %%
df[(df["new_col2"].isnull())]
# Out:
#     ID     crim    zn  indus  chas    nox     rm  age     dis  rad  tax  \
# 2    4  0.03237   0.0   2.18     0  0.458  6.998   45  6.0622    3  222
# 4    7  0.08829  12.5   7.87     0  0.524  6.012   66  5.5605    5  311
# 9   15  0.63796   0.0   8.14     0  0.538  6.096   84  4.4619    4  307
# 13  21  1.25179   0.0   8.14     0  0.538  5.570   98  3.7979    4  307
#
#     ptratio   black  lstat  medv  new_col  new_col2
# 2      18.7  394.63   2.94  33.4        1       NaN
# 4      15.2  395.60  12.43  22.9        1       NaN
# 9      21.0  380.02  10.26  18.2        0       NaN
# 13     21.0  376.57  21.02  13.6        0       NaN

# %%
#df.dropna()
df["new_col2"].fillna(df["new_col2"].median(), inplace = True)

# %% [markdown]
# ## Indexing and slicing

# %%
df.iloc[3]
# Out:
# ID            5.00000
# crim          0.06905
# zn            0.00000
# indus         2.18000
# chas          0.00000
# nox           0.45800
# rm            7.14700
# age          54.00000
# dis           6.06220
# rad           3.00000
# tax         222.00000
# ptratio      18.70000
# black       396.90000
# lstat         5.33000
# medv         36.20000
# new_col       0.00000
# new_col2     30.00000
# Name: 3, dtype: float64

# %%
df.iloc[3][4]
# Out:
# 0.0

# %%
df.iloc[3:6, :]
# Out:
#    ID     crim    zn  indus  chas    nox     rm  age     dis  rad  tax  \
# 3   5  0.06905   0.0   2.18     0  0.458  7.147   54  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012   66  5.5605    5  311
# 5  11  0.22489  12.5   7.87     0  0.524  6.377   94  6.3467    5  311
#
#    ptratio   black  lstat  medv  new_col  new_col2
# 3     18.7  396.90   5.33  36.2        0      30.0
# 4     15.2  395.60  12.43  22.9        1      52.0
# 5     15.2  392.52  20.45  15.0        1      19.0

# %%
df.iloc[3:6, 4:6]
# Out:
#    chas    nox
# 3     0  0.458
# 4     0  0.524
# 5     0  0.524

# %%
df.iloc[4,6] = 5
print(df.iloc[4,6])
# Out:
# 5.0

# %%
df["new_col3"] = np.zeros(df.shape[0],)

# %%
df.loc[(df["age"] >= 60), "new_col3"] = 1

# %%
df[["age", "new_col3"]]
# Out:
#      age  new_col3
# 0     65       1.0
# 1     78       1.0
# 2     45       0.0
# 3     54       0.0
# 4     66       1.0
# 5     94       1.0
# 6     82       1.0
# 7     39       0.0
# 8     61       1.0
# 9     84       1.0
# 10    56       0.0
# 11    29       0.0
# 12    36       0.0
# 13    98       1.0
# 14    89       1.0
# 15    91       1.0
# 16   100       1.0
# 17    88       1.0
# 18    94       1.0
# 19   100       1.0
# 20    96       1.0
# 21    30       0.0
# 22    21       0.0
# 23    15       0.0
# 24     6       0.0
# 25     6       0.0
# 26    40       0.0
# 27    33       0.0
# 28    33       0.0
# 29    85       1.0
# ..   ...       ...
# 303   65       1.0
# 304   48       0.0
# 305   84       1.0
# 306   94       1.0
# 307   71       1.0
# 308   56       0.0
# 309   90       1.0
# 310   75       1.0
# 311   95       1.0
# 312   93       1.0
# 313   97       1.0
# 314   96       1.0
# 315   88       1.0
# 316   64       1.0
# 317   74       1.0
# ...

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#     ID      crim   zn  indus  chas    nox     rm  age     dis  rad  tax  \
# 0  146   2.37934  0.0  19.58     0  0.871  6.130  100  1.4191    5  403
# 1  371   6.53876  0.0  18.10     1  0.631  7.016   97  1.2024   24  666
# 2  378   9.82349  0.0  18.10     0  0.671  6.794   98  1.3580   24  666
# 3  341   0.06151  0.0   5.19     0  0.515  5.968   58  4.8122    5  224
# 4  479  10.23300  0.0  18.10     0  0.614  6.185   96  2.1705   24  666
#
#    ptratio   black  lstat  medv  new_col  new_col2  new_col3
# 0     14.7  172.91  27.80  13.8        0      30.0       1.0
# 1     20.2  392.05   2.96  50.0        1      45.0       1.0
# 2     20.2  396.90  21.24  13.3        0      64.0       1.0
# 3     20.2  396.90   9.29  18.7        0      18.0       0.0
# 4     20.2  379.70  18.03  14.6        1       1.0       1.0
